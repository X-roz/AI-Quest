# %% [markdown]
# ## WaterShed Algorithm

# %% [raw]
# In Geography, watershed is a land area that channels rainfall into river/stream and that eventually outflows to ocean/reservoirs.
# These watersheds can then segmented as topographical maps with boundries.
#
# Likewise, Watershed algorithm works with images, the brightness of the each point representing its height, and find the lines that runs along the tops of the ridges.
#
# Any grayscale image can be viewed as topographic surface where high intensity denotes peak and hills while low intensity denotes valleys.
#
# The alogorithm can then fill every isolated valleys with different colored water. This algorithm is especially useful for segmenting images into background and foreground in situations that are difficult for other algorithms.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# display images
def display(img):
    plt.figure(figsize=(12,10)).add_subplot(111)
    plt.imshow(img, cmap='gray')
    plt.show()

# %%
img = cv2.imread("../dataset/img/coins.jpg" ,0)
display(img)
